# %% [markdown]
# <a href="https://colab.research.google.com/github/MehakSetia/my-gen-ai-projects/blob/main/gen_ai_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Save ouput to file

# %%
from transformers import pipeline
import os

os.makedirs("outputs", exist_ok=True)

def generate_save(prompt,filename="output.txt"):
  generator=pipeline("text-generation",model="gpt2-medium")

  output=generator(
      prompt,
      repetition_penalty=1.5,
      temperature=0.7, # for randomness, 0.7 is balanced(default)
      truncation=True  # silences warning
  )[0]['generated_text']

  with open(filename,"w") as f:
    f.write(output)

    print(f"Saved to {filename}")
    return output

while True:
  prompt=input("Enter the prompt or quit: ")
  if prompt.lower()=="quit":
    break
  output=generate_save(prompt)
  print(output)
# Out:
# Enter the prompt or quit: AI is
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saved to output.txt
# AI is not going anywhere. It's a good example to illustrate the fact that we should be wary of any new technology, especially if it may cause unintended consequences."
#  I'd like "good" people who have been on this journey for decades and are still doing fine without having yet seen anything come along in their lifetimes — even though they were warned about risk by experts when someone tried something (and really didn't figure out what was causing it until later). They're likely well-informed enough already with all the history behind them so there must justbe nothing left at all…yet….they continue getting sicker as time goes forward; often suffering from serious health problems including heart disease or cancer which eventually lead directly into death itself! This includes those born after 1970 according my calculations:
#
#  (Source)
# Enter the prompt or quit: quit

# %% [markdown]
# Auto-name files

# %%
from transformers import pipeline
import os

os.makedirs("outputs", exist_ok=True)

def generate_save(prompt):
  filename=f"outputs/{prompt[:20].strip().replace(' ','_')}.txt"
  generator=pipeline("text-generation",model="gpt2-medium")

  output=generator(
      prompt,
      repetition_penalty=1.5,
      temperature=0.7, # for randomness, 0.7 is balanced(default)
      truncation=True  # silences warning
  )[0]['generated_text']

  with open(filename,"w") as f:
    f.write(output)

    print(f"Saved to {filename}")
    return output

while True:
  prompt=input("Enter the prompt or quit: ")
  if prompt.lower()=="quit":
    break
  output=generate_save(prompt)
  print(output)
# Out:
# Enter the prompt or quit: "Explain neural networks in 3 bullet points:"
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saved to outputs/"Explain_neural_netw.txt
# "Explain neural networks in 3 bullet points:"
# I love that you're making the argument about how a new technology is going to make certain kinds of data analysis more efficient and thus better. I don't see what's wrong with this, though; just as one can learn on an airplane if it has been trained correctly by some good pilot during flight or otherwise done so unconsciously for decades (as explained above), we should be taught at least basic information processing techniques whenever possible before using computer-based methods like image recognition when needed." But my point here isn`t really because there are any arguments against machine learning -- but rather simply saying "it would seem pretty cool not only once these systems get started now, BUT also later!" It seems obvious right? This could happen! And no doubt even after years they will find improvements from time spent training them properly. So why does Google still insist upon doing all their work without user input? Why doesn�nt anyone else want to do anything related instead?
# Enter the prompt or quit: "Write a clean Python function for Fibonacci sequence with type hints:"
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saved to outputs/"Write_a_clean_Pytho.txt
# "Write a clean Python function for Fibonacci sequence with type hints:"
# But the syntax is still not clear to me. And it's actually impossible for both myself and others in this thread (including some very experienced people) at least even on OSX: http://bitcointalk,forum/index-topic...sicle10781470#p15431754 This code does one thing wrong that doesn't need another command line tool like python2c. It uses an incorrect "array". If I have understood correctly what you're trying do by using array(), then why should anyone else? The first time i tried reading about arrays from Cython 2 before writing my own version of fibonadic_sequence(a : int): 0x00000500000...and there are many similar mistakes here as well https:/ /codeaurora dot com/  filetype4py1uq7j8hmfw3e65y0kfd6dgv5t9o30i67znbcfbc66lmdwnr83iy
# Enter the prompt or quit: quit

# %% [markdown]
# improving the ouput

# %%
from transformers import pipeline
import os

os.makedirs("outputs", exist_ok=True)

def generate_save(prompt):
  filename=f"outputs/{prompt[:20].strip().replace(' ','_')}.txt"
  generator=pipeline("text-generation",model="facebook/opt-1.3b")

  output=generator(
      prompt+"\n",
      max_new_tokens=300,
      repetition_penalty=2.0,
      temperature=0.3,
      truncation=True
  )[0]['generated_text']

  with open(filename,"w") as f:
    f.write(output)

    print(f"Saved to {filename}")
    return output

while True:
  prompt=input("Enter the prompt or quit: ")
  if prompt.lower()=="quit":
    break
  output=generate_save(prompt)
  print(output)
# Out:
# Enter the prompt or quit: write a haiku about AI
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.63G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# Device set to use cuda:0
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Saved to outputs/write_a_haiku_about.txt
# write a haiku about AI
# I'm not sure if you're serious or joking, but I'll give it my best shot.  *Ai is the future* - Haikus are for kids! (It's an old joke that has been around forever.) A-Is will be smarter than us in no time at all and we won't even know what to do with ourselves when they take over everything...and then kill themselves because of their own stupidity? That would make me sad :( But hey maybe one day.. :) Thanks anyway though!! :D Have fun writing your poem!!! =) <3 xoxo~ ♥♥♡❤️😘💕✨👌☺⛄#AI #ArtificialIntelligence 📚 pic by @sarah_albany on Instagram ❣︎ (@SarahAlbanyOfficial ) May 21st 2019 See more posts like this... Follow Sarah Albanian Photography Twitter Facebook Pinterest Tumblr Google+ LinkedIn Email Print More Posts » Comment: Leave Your Comments Here Please note comments may have had some adverts removed from them as part Of our ongoing efforts To keep things clean & safe For those who use AdBlockers please disable yours so these ads don’t appear again Thank You! ✅ Posted By SARA ALBANY Last updated 1 week ago This website uses cookies which help improve its performance And remember social media links can contain affiliate marketing messages So click here If any issues arise feel free email info@j
# Enter the prompt or quit: quit
