# %% [markdown]
# <a href="https://colab.research.google.com/github/MehakSetia/my-gen-ai-projects/blob/main/gen_ai_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Save ouput to file

# %%
from transformers import pipeline
import os

os.makedirs("outputs", exist_ok=True)

def generate_save(prompt,filename="output.txt"):
  generator=pipeline("text-generation",model="gpt2-medium")

  output=generator(
      prompt,
      repetition_penalty=1.5,
      temperature=0.7, # for randomness, 0.7 is balanced(default)
      truncation=True  # silences warning
  )[0]['generated_text']

  with open(filename,"w") as f:
    f.write(output)

    print(f"Saved to {filename}")
    return output

while True:
  prompt=input("Enter the prompt or quit: ")
  if prompt.lower()=="quit":
    break
  output=generate_save(prompt)
  print(output)
# Out:
# Enter the prompt or quit: AI is
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saved to output.txt
# AI is a global network of scientists, engineers and technologists dedicated to improving the lives in developing countries. We believe that every person has an equal right as long at this moment we are able (and willing) be here on Earth."
# Enter the prompt or quit: quit

# %% [markdown]
# Auto-name files

# %%
from transformers import pipeline
import os

os.makedirs("outputs", exist_ok=True)

def generate_save(prompt):
  filename=f"outputs/{prompt[:20].strip().replace(' ','_')}.txt"
  generator=pipeline("text-generation",model="gpt2-medium")

  output=generator(
      prompt,
      repetition_penalty=1.5,
      temperature=0.7, # for randomness, 0.7 is balanced(default)
      truncation=True  # silences warning
  )[0]['generated_text']

  with open(filename,"w") as f:
    f.write(output)

    print(f"Saved to {filename}")
    return output

while True:
  prompt=input("Enter the prompt or quit: ")
  if prompt.lower()=="quit":
    break
  output=generate_save(prompt)
  print(output)
# Out:
# Enter the prompt or quit: neural networks are
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saved to outputs/neural_networks_are.txt
# neural networks are found in both species, and a number of studies show that these circuits play important roles during motor learning. Thus by studying the neural correlates for complex movements such as jumping we can learn how to perform them at higher speeds than if they were learned simply from visual cues alone [26] – 32.
#  "Kicking" is an old sport with some very ancient origins but it has recently gained popularity internationally following more recent developments (such ASICS shoes) through social media; however there never was any scientific evidence linking this activity directly or indirectly between exercise levels/phases 1–3 and brain function prior-to cognitive training methods."It's amazing what you're missing out on," says Dr Finkman who conducted his own research into neurophysiological responses associated not only specifically using leg kicks after knee injuries,but also those performed via hand crunches while cycling 60+ km per week across 10 countries over two years".In our study participants completed tasks measured beforehand based off their level when performing either foot kicking drills 2 minutes before stepping onto each trial phase where individuals varied legs kicked 90 cm apart without getting tired due to time spent walking away along trials within 30 seconds then completing 3 consecutive phases measuring different conditions consisting predominantly running steps accompanied primarily done up movement patterns including forward pushdowns followed
# Enter the prompt or quit: quit

# %% [markdown]
# improving the ouput

# %%
from transformers import pipeline
import os

os.makedirs("outputs", exist_ok=True)

def generate_save(prompt):
  filename=f"outputs/{prompt[:20].strip().replace(' ','_')}.txt"
  generator=pipeline("text-generation",model="facebook/opt-1.3b")

  output=generator(
      prompt+"\n",
      max_new_tokens=300,
      repetition_penalty=2.0,
      temperature=0.3,
      truncation=True
  )[0]['generated_text']

  with open(filename,"w") as f:
    f.write(output)

    print(f"Saved to {filename}")
    return output

while True:
  prompt=input("Enter the prompt or quit: ")
  if prompt.lower()=="quit":
    break
  output=generate_save(prompt)
  print(output)
# Out:
# Enter the prompt or quit: write a haiku about AI
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.63G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# Device set to use cuda:0
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Saved to outputs/write_a_haiku_about.txt
# write a haiku about AI
# I'm not sure if you're serious or joking, but I'll give it my best shot.  *Ai is the future* - Haikus are for kids! (It's an old joke that has been around forever.) A-Is will be smarter than us in no time at all and we won't even know what to do with ourselves when they take over everything...and then kill themselves because of their own stupidity? That would make me sad :( But hey maybe one day.. :) Thanks anyway though!! :D Have fun writing your poem!!! =) <3 xoxo~ ♥♥♡❤️😘💕✨👌☺⛄#AI #ArtificialIntelligence 📚 pic by @sarah_albany on Instagram ❣︎ (@SarahAlbanyOfficial ) May 21st 2019 See more posts like this... Follow Sarah Albanian Photography Twitter Facebook Pinterest Tumblr Google+ LinkedIn Email Print More Posts » Comment: Leave Your Comments Here Please note comments may have had some adverts removed from them as part Of our ongoing efforts To keep things clean & safe For those who use AdBlockers please disable yours so these ads don’t appear again Thank You! ✅ Posted By SARA ALBANY Last updated 1 week ago This website uses cookies which help improve its performance And remember social media links can contain affiliate marketing messages So click here If any issues arise feel free email info@j
# Enter the prompt or quit: quit
